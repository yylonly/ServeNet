# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize

# %%
data = [
  {
    'name': {
      'first': 'vikash',
      'last': 'singh'
    },
    'age': 27
  },
  {
    'name': {
      'first': 'satyam',
      'last': 'singh'
    },
    'age': 14
  }
]

# %%
df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
df
# Out:
#    age name.first name.last
# 0   27     vikash     singh
# 1   14     satyam     singh

# %%
with open('ProgrammWebScrapy.txt', encoding='utf-8') as data_file:
    f = data_file.read()
    data = json.loads(f, strict=False)

# %%
df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
df
# Out:
#                                              APIEndpoint  \
# 0                  https://www.google.com/maps/embed/v1/
# 1                           http://twitter.com/statuses/
# 2                     https://www.youtube.com/iframe_api
# 3                        http://api.flickr.com/services/
# 4                 http://api.facebook.com/restserver.php
# 5                         http://webservices.amazon.com/
# 6                      https://api.twilio.com/2010-04-01
# 7                      http://ws.audioscrobbler.com/2.0/
# 8      http://developer.ebay.com/webservices/latest/e...
# 9                                                    NaN
# 10           See-> http://dev.live.com/virtualearth/sdk/
# 11                           https://api.del.icio.us/v1/
# 12                                                   NaN
# 13                        https://api.foursquare.com/v2/
# 14                                                   NaN
# 15            https://demo.docusign.net/api/3.0/api.asmx
# 16                              http://s3.amazonaws.com/
# 17     http://code.google.com/apis/adsense/developer/...
# 18                              http://api.geonames.org/
# 19                    https://en.wikipedia.org/w/api.php
# 20                              https://api.box.com/2.0/
# 21     http://ec2.amazonaws.com/doc/2006-06-26/Amazon...
# 22     https://api.cognitive.microsoft.com/bing/v7.0/...
# 23                           http://api.linkedin.com/v1/
# 24                                    graph.facebook.com
# 25                https://ajax.googleapis.com/ajax/libs/
# 26     http://yboss.yahooapis.com/ysearch/{vertical}?...
# 27                                   http://api.yelp.com
# 28                                                   NaN
# 29               https://www.googleapis.com/analytics/v3
# ...                                                  ...
# 15314                http://www.ratepubs.com/freecontent
# 15315                   http://requests.wipeelist.com/v1
# 15316                 http://api.virwox.com/api/json.php
# 15317          https://openeco.org/module/object/id/xml/
# 15318                        http://manage.encoding.com/
# 15319  http://api.webresizer.com/ext/js/webresizer_ap...
# 15320                           http://dooblet.com/feeds
# 15321                   https://company.tickspot.com/api
# 15322       http://User:Pass@www.dilogs.com/Language/api
# 15323                                   http://to.uri.st
# 15324                            http://api.adspeed.com/
# 15325                       http://simpledb.appspot.com/
# 15326                       http://tweetburner.com/links
# 15327                                                NaN
# 15328               http://api.FindMeOn.com/v1/findmeon/
# 15329                         https://api.gogrid.com/api
# 15330                    http://www.seattle20.com/api/v1
# 15331                                                NaN
# 15332                    https://todoist.com/API/v6/sync
# 15333                http://pingthesemanticweb.com/rest/
# 15334                  http://my.phonegnome.com/controls
# 15335                      http://walkertracker.com/api/
# 15336            http://api.dojolearning.com/rest-action
# 15337                                                NaN
# 15338                           http://izearanks.com/api
# 15339                           http://xmlrpc.mollom.com
# 15340  http://v1.fraudlabs.com/mailboxvalidatorwebser...
# 15341                             http://weewar.com/api1
# 15342  http://www.xignite.com/product/global-stock-qu...
# 15343                               http://rest.pdbj.org
#
#                                    APIForumMessageBoards  \
# 0      http://groups-beta.google.com/group/Google-Map...
# 1      http://groups.google.com/group/twitter-develop...
# 2            http://groups.google.com/group/youtube-api/
# 3                       http://www.flickr.com/groups/api
# 4                  http://forum.developers.facebook.com/
# 5      http://developer.amazonwebservices.com/connect...
# 6                            https://www.twilio.com/blog
# 7      http://www.last.fm/group/Last.fm+Web+Services/...
# 8            http://developer.ebay.com/community/forums/
# 9         http://forum.twilio.com/twilio/?from_gsfn=true
# 10     http://social.msdn.microsoft.com/forums/en-US/...
# 11     http://support.delicious.com/forum/index.php?C...
# 12       http://groups.google.com/group/google-appengine
# 13     https://stackoverflow.com/questions/tagged/fou...
# 14     http://groups.google.com/group/Google-Gadgets-API
# 15     http://stackoverflow.com/questions/tagged/docu...
# 16     http://developer.amazonwebservices.com/connect...
# 17     http://groups.google.com/group/AdSense-API/topics
# 18      https://groups.google.com/forum/#!forum/geonames
# 19                                                   NaN
# 20     https://community.box.com/t5/Developer-Forum/b...
# 21     http://developer.amazonwebservices.com/connect...
# 22     https://stackoverflow.com/questions/tagged/bin...
# 23                                                   NaN
# 24     https://groups.google.com/forum/#!forum/instag...
# 25     http://groups.google.com/group/Google-AJAX-Sea...
# 26       http://tech.groups.yahoo.com/group/ysearchboss/
# 27                   https://github.com/yelp/yelp-fusion
# 28                                                   NaN
# 29     https://developers.google.com/analytics/commun...
# ...                                                  ...
# 15314                                                NaN
# 15315                                                NaN
# 15316                                                NaN
# 15317           https://www.openeco.org/forum/topic/4213
# 15318                                                NaN
# 15319                                                NaN
# 15320                                                NaN
# 15321                                                NaN
# 15322                                                NaN
# 15323                                                NaN
# 15324                                                NaN
# 15325                                                NaN
# 15326                                                NaN
# 15327                                                NaN
# 15328                                                NaN
# 15329       http://wiki.gogrid.com/wiki/index.php/Forums
# 15330                                                NaN
# 15331                                                NaN
# 15332                                                NaN
# 15333                                                NaN
# 15334  http://www.phonegnome.com/support/index.php?na...
# 15335                                                NaN
# 15336                                                NaN
# 15337                                                NaN
# 15338                                                NaN
# 15339                            http://mollom.com/forum
# 15340                                                NaN
# 15341         http://weewar.com/forum/forums/show/5.page
# 15342  http://resources.xignite.com/h/c/190077-xignit...
# 15343                                                NaN
#
#                                        APIPortalHomePage APIProvider  \
# 0                    https://developers.google.com/maps/      Google
# 1                    https://dev.twitter.com/rest/public     Twitter
# 2                 https://developers.google.com/youtube/      Google
# 3                    http://www.flickr.com/services/api/      Flickr
# 4                       https://developers.facebook.com/    Facebook
# 5      https://affiliate-program.amazon.com/gp/advert...      Amazon
# 6                                  http://www.twilio.com      Twilio
# 7                                 http://www.last.fm/api     Last.fm
# 8          https://go.developer.ebay.com/developers/ebay         NaN
# 9                              http://www.twilio.com/sms         NaN
# 10     http://www.microsoft.com/maps/choose-your-bing...   Microsoft
# 11               https://delicious.com/developers#title1         NaN
# 12              https://developers.google.com/appengine/         NaN
# 13                     https://developer.foursquare.com/  Foursquare
# 14                https://developers.google.com/gadgets/         NaN
# 15             https://www.docusign.com/developer-center    DocuSign
# 16                             http://aws.amazon.com/s3/      Amazon
# 17                https://developers.google.com/adsense/         NaN
# 18                       http://www.geonames.org/export/    GeoNames
# 19                     http://www.mediawiki.org/wiki/API   Wikipedia
# 20               https://box-content.readme.io/reference         Box
# 21     http://docs.aws.amazon.com/AWSEC2/latest/APIRe...      Amazon
# 22     https://azure.microsoft.com/en-us/services/cog...         NaN
# 23                   https://developer.linkedin.com/docs    LinkedIn
# 24     https://developers.facebook.com/docs/instagram...   Instagram
# 25     https://developers.google.com/speed/libraries/...      Google
# 26               http://developer.yahoo.com/boss/search/       Yahoo
# 27                       https://www.yelp.com/developers        Yelp
# 28                                   https://api.asot.fm         NaN
# 29     https://developers.google.com/analytics/devgui...      Google
# ...                                                  ...         ...
# 15314  http://www.ratepubs.com/freecontent/freeconten...         NaN
# 15315                      http://www.wipeelist.com/api/         NaN
# 15316       https://www.virwox.com/developers.php?drgn=3         NaN
# 15317                  https://www.openeco.org/developer         NaN
# 15318                           http://api.encoding.com/         NaN
# 15319                         http://webresizer.com/app/         NaN
# 15320                    http://dooblet.com/feeds/api/_/         NaN
# 15321                       http://www.tickspot.com/api/         NaN
# 15322                     http://reservasbuceo.es/dilogs         NaN
# 15323               http://tourist.wikispaces.com/webapi         NaN
# 15324  http://www.adspeed.com/Knowledges/830/AdSpeed_...         NaN
# 15325                       http://simpledb.appspot.com/         NaN
# 15326                         http://tweetburner.com/api         NaN
# 15327  http://www.wordpot.com/WebServices/WordpotWebS...         NaN
# 15328                           http://api.findmeon.com/         NaN
# 15329              https://wiki.gogrid.com/index.php/Api         NaN
# 15330                http://www.geekwire.com/seattle-20/         NaN
# 15331          http://content.freedomspeaks.com/api.aspx         NaN
# 15332                            http://todoist.com/API/     Todoist
# 15333              http://pingthesemanticweb.com/api.php         NaN
# 15334                      http://my.phonegnome.com/api/         NaN
# 15335             http://api.walkertracker.com/api/docs/         NaN
# 15336             http://www.dojolearning.com/api-action         NaN
# 15337                  http://landgrab.net/landgrab/api/         NaN
# 15338                     http://izearanks.com/api/about         NaN
# 15339                              http://mollom.com/api         NaN
# 15340     http://www.fraudlabs.com/mailboxvalidator.aspx    Hexasoft
# 15341                              http://weewar.com/api         NaN
# 15342  http://www.xignite.com/product/global-stock-qu...         NaN
# 15343                     http://pdbj.org/#!help?PID=515         NaN
#
#       ArchitecturalStyle                                AuthenticationModel  \
# 0                   REST                                            API Key
# 1                   REST                                            OAuth 2
# 2                   REST                                            API Key
# 3                   REST                                            OAuth 1
# 4                   REST                                   API Key, OAuth 2
# 5                   REST                                            API Key
# 6                   REST                           API Key, HTTP Basic Auth
# 7                   REST                      API Key, Shared Secret, Token
# 8                   REST                                                NaN
# 9                   REST                                                NaN
# 10              Indirect                                            API Key
# 11                  REST                                                NaN
# 12                   NaN                                                NaN
# 13                  REST              App ID, OAuth 2, Shared Secret, Token
# 14                  REST                                                NaN
# 15                  REST  API Key, HTTP Basic Auth, OAuth 2, SAML, Token...
# 16                  REST                             API Key, Shared Secret
# 17                  REST                                                NaN
# 18                  REST                                        Unspecified
# 19                  REST                                            OAuth 1
# 20                  REST              API Key, OAuth 2, Other/Custom, Token
# 21                  REST                                            API Key
# 22                  REST                                            API Key
# 23                  REST                                            OAuth 2
# 24                  REST                                              Token
# 25                   NaN                                                NaN
# 26                  REST                                   API Key, OAuth 1
# 27                  REST                                            API Key
# 28                  REST                                                NaN
# 29                  REST                                            OAuth 2
# ...                  ...                                                ...
# 15314               REST                                                NaN
# 15315               REST                                                NaN
# 15316               REST                                                NaN
# 15317               REST                                                NaN
# 15318               REST                                                NaN
# 15319                NaN                                                NaN
# 15320               REST                                                NaN
# 15321               REST                                                NaN
# 15322               REST                                                NaN
# 15323               REST                                                NaN
# 15324               REST                                                NaN
# 15325               REST                                                NaN
# 15326               REST                                                NaN
# 15327                RPC                                                NaN
# 15328               REST                                                NaN
# 15329               REST                                                NaN
# 15330               REST                                                NaN
# 15331               REST                                                NaN
# 15332               REST                                            API Key
# 15333               REST                                                NaN
# 15334               REST                                                NaN
# 15335               REST                                                NaN
# 15336               REST                                                NaN
# 15337                RPC                                                NaN
# 15338               REST                                                NaN
# 15339               REST                                                NaN
# 15340                RPC                                            API Key
# 15341               REST                                                NaN
# 15342               REST                                              Token
# 15343               REST                                                NaN
#
#                                              Description DeviceSpecific  \
# 0      Google Maps' services have been split into mul...             No
# 1      It has been split into multiple APIs, includin...             No
# 2      The Data API allows users to integrate their p...             No
# 3      The Flickr API can be used to retrieve photos ...             No
# 4      Its functions have been split among the follow...             No
# 5      What was formerly the ECSeCommerce Servicehas ...             No
# 6      Twilio provides a simple hosted API and markup...             No
# 7      The Last.fm API gives users the ability to bui...             No
# 8      eBay's primary web services are found in the t...             No
# 9      Twilio provides a simple hosted API and markup...             No
# 10     Bing Maps API and Interactive SDK features an ...             No
# 11     del.icio.us is a social bookmarking website th...             No
# 12     Use the Google App Engine platform to run web ...             No
# 13     The Foursquare API provides location based exp...             No
# 14     The Google Gadgets API provides a way to put t...             No
# 15     DocuSign is a Cloud based legally compliant eS...             No
# 16     Since 2006 Amazon Web Services has been offeri...             No
# 17     The Google AdSense API is ideal for developers...             No
# 18     Geonames is a geographical database with web s...             No
# 19     The unofficial Wikipedia API. Because Wikipedi...             No
# 20     Box is a modern content management platform th...             No
# 21     The Amazon Elastic Compute Cloud (Amazon EC2) ...             No
# 22     Bing Web Search API provides an experience sim...             No
# 23     LinkedIn is the world's largest business socia...             No
# 24     Instagram is a photo sharing iPhone app and se...             No
# 25     The AJAX Libraries API is a content distributi...             No
# 26     Per provider, this API will be shutting down o...             No
# 27     The Yelp Fusion APIs are RESTful APIs and user...             No
# 28     A State of Trance is a radio show, hosted by A...             No
# 29     Use the Google Analytics Management API to lev...             No
# ...                                                  ...            ...
# 15314  Use the RatePubs API to get two-way access to ...             No
# 15315  Use the Wipee List API to extend Wipee List or...             No
# 15316  Use the VirWoX API to exchange virtual currenc...             No
# 15317  The OpenEco API allows you to track your green...             No
# 15318  Encoding.com lets you encode and transcode vid...             No
# 15319  WebResizer is an image editor you can embed in...             No
# 15320  Use the Dooblet API to get two alternatives to...             No
# 15321  The TickSpot API lets you retrieve a list of c...             No
# 15322  Use the Dilogs API to get your dives, post you...             No
# 15323  Use the to.uri.st API to access tourist inform...             No
# 15324  Use the AdSpeed API to access your zones, ads,...             No
# 15325  Use the Simple DB on AppEngine API to store da...             No
# 15326  Tweetburner is the webservice that lets you sh...             No
# 15327  The Wordpot.com API provides functions for gen...             No
# 15328  Use the FindMeOn API to manage your identities...             No
# 15329  Use the GoGrid API to do everything programmat...             No
# 15330  Use the Seattle 2.0 API to get upcoming events...             No
# 15331  The FreedomSpeaks.com site is the first non-pa...             No
# 15332  Todoist is an online task manager that current...             No
# 15333  Ping the Semantic Web is a repository for RDF ...             No
# 15334  PhoneGnome is a hardware-to-internet service t...             No
# 15335  Walker Tracker is a site for pedometer enthusi...             No
# 15336  Use the Dojo Learning API to access lessons, u...             No
# 15337  LandGrab is an easy-to-play game that connects...             No
# 15338  IZEARanks provides a blog ranking algorithm an...             No
# 15339  Use the Mollom API to combat spam. Mollom is a...             No
# 15340  Use the MailBoxValidator Email Validation Web ...             No
# 15341  The Weewar API allows you to create notifiers,...             No
# 15342  This API offers delayed stock quotes for equit...             No
# 15343  Use the Protein Data Bank Japan (PDBj) API to ...             No
#
#                                           DocsHomePageUR  \
# 0                    https://developers.google.com/maps/
# 1                    https://dev.twitter.com/rest/public
# 2                 https://developers.google.com/youtube/
# 3                    http://www.flickr.com/services/api/
# 4                       https://developers.facebook.com/
# 5      https://docs.aws.amazon.com/AWSECommerceServic...
# 6                   https://www.twilio.com/docs/api/rest
# 7                                 http://www.last.fm/api
# 8          https://go.developer.ebay.com/developers/ebay
# 9                              http://www.twilio.com/sms
# 10     http://www.microsoft.com/maps/choose-your-bing...
# 11                                                   NaN
# 12              https://developers.google.com/appengine/
# 13                 https://developer.foursquare.com/docs
# 14                https://developers.google.com/gadgets/
# 15             https://www.docusign.com/developer-center
# 16     https://docs.aws.amazon.com/AmazonS3/latest/AP...
# 17                https://developers.google.com/adsense/
# 18      http://www.geonames.org/export/web-services.html
# 19                     http://www.mediawiki.org/wiki/API
# 20                             https://docs.box.com/docs
# 21     http://docs.aws.amazon.com/AWSEC2/latest/APIRe...
# 22     https://docs.microsoft.com/en-us/azure/cogniti...
# 23          https://developer.linkedin.com/docs/rest-api
# 24     https://developers.facebook.com/docs/instagram...
# 25     https://developers.google.com/speed/libraries/...
# 26               http://developer.yahoo.com/boss/search/
# 27                        http://www.yelp.com/developers
# 28                                   https://api.asot.fm
# 29     https://developers.google.com/analytics/devgui...
# ...                                                  ...
# 15314  http://www.ratepubs.com/freecontent/freeconten...
# 15315                                                NaN
# 15316       https://www.virwox.com/developers.php?drgn=3
# 15317                                                NaN
# 15318                           http://api.encoding.com/
# 15319                         http://webresizer.com/app/
# 15320                    http://dooblet.com/feeds/api/_/
# 15321                       http://www.tickspot.com/api/
# 15322                     http://reservasbuceo.es/dilogs
# 15323               http://tourist.wikispaces.com/webapi
# 15324  http://www.adspeed.com/Knowledges/830/AdSpeed_...
# 15325                                                NaN
# 15326                         http://tweetburner.com/api
# 15327                                                NaN
# 15328                                                NaN
# 15329                                                NaN
# 15330                http://www.geekwire.com/seattle-20/
# 15331                                                NaN
# 15332                            http://todoist.com/API/
# 15333                                                NaN
# 15334                      http://my.phonegnome.com/api/
# 15335             http://api.walkertracker.com/api/docs/
# 15336             http://www.dojolearning.com/api-action
# 15337                                                NaN
# 15338                     http://izearanks.com/api/about
# 15339                              http://mollom.com/api
# 15340     http://www.fraudlabs.com/mailboxvalidator.aspx
# 15341                                                NaN
# 15342  http://www.xignite.com/product/global-stock-qu...
# 15343                     http://pdbj.org/#!help?PID=515
#
#       IsThisanUnofficialAPI IstheAPIDesign                  PrimaryCategory  \
# 0                        No             No                          Mapping
# 1                        No            Yes                           Social
# 2                        No             No                            Video
# 3                        No             No                           Photos
# 4                        No             No                           Social
# 5                        No            Yes                        eCommerce
# 6                        No             No                        Telephony
# 7                        No            Yes                            Music
# 8                        No             No                           Search
# 9                        No             No                        Messaging
# 10                       No             No                          Mapping
# 11                       No             No                        Bookmarks
# 12                       No             No                            Tools
# 13                       No             No                           Social
# 14                       No             No                          Widgets
# 15                       No            Yes             Electronic Signature
# 16                       No             No                          Storage
# 17                       No             No                      Advertising
# 18                       No            Yes                        Reference
# 19                      Yes            Yes                        Reference
# 20                       No             No                          Content
# 21                       No             No                            Cloud
# 22                       No             No                           Search
# 23                       No             No                           Social
# 24                       No            Yes                           Photos
# 25                       No             No                          Library
# 26                       No             No                           Search
# 27                       No             No                  Recommendations
# 28                       No             No                            Music
# 29                       No             No                        Analytics
# ...                     ...            ...                              ...
# 15314                    No             No                             Food
# 15315                    No             No               Project Management
# 15316                    No             No                        Financial
# 15317                    No             No                            Other
# 15318                    No             No                            Video
# 15319                    No             No                           Photos
# 15320                    No             No                           Search
# 15321                    No             No               Project Management
# 15322                    No             No                           Sports
# 15323                    No             No                           Travel
# 15324                    No             No                      Advertising
# 15325                    No             No                          Storage
# 15326                    No             No                           Social
# 15327                    No             No                      Advertising
# 15328                    No             No                           Social
# 15329                    No             No                            Cloud
# 15330                    No             No                           Events
# 15331                    No             No                       Government
# 15332                    No             No  Personal Information Management
# 15333                    No             No                        Standards
# 15334                    No             No                        Telephony
# 15335                    No             No                           Sports
# 15336                    No             No                       Enterprise
# 15337                    No             No                            Games
# 15338                    No             No                         Blogging
# 15339                    No             No                         Security
# 15340                    No             No                            Email
# 15341                    No             No                            Games
# 15342                    No             No                        Financial
# 15343                    No             No                          Medical
#
#       RestrictedAccess SSLSupport               Scope  \
# 0                   No         No  Single purpose API
# 1                   No         No  Single purpose API
# 2                   No         No  Single purpose API
# 3                   No        Yes  Single purpose API
# 4                   No        Yes  Single purpose API
# 5                  Yes         No  Single purpose API
# 6                   No        Yes  Single purpose API
# 7                   No         No  Single purpose API
# 8                   No        Yes  Single purpose API
# 9                   No        Yes  Single purpose API
# 10                  No        Yes  Single purpose API
# 11                  No        Yes  Single purpose API
# 12                  No        Yes  Single purpose API
# 13                 Yes        Yes  Single purpose API
# 14                  No        NaN  Single purpose API
# 15                  No        Yes  Single purpose API
# 16                 Yes        Yes  Single purpose API
# 17                  No        Yes  Single purpose API
# 18                  No        Yes  Single purpose API
# 19                  No        Yes  Single purpose API
# 20                  No        Yes  Single purpose API
# 21                  No        Yes     Metaservice API
# 22                  No        Yes  Single purpose API
# 23                 Yes        Yes  Single purpose API
# 24                  No        Yes  Single purpose API
# 25                  No        Yes  Single purpose API
# 26                  No        Yes  Single purpose API
# 27                  No        Yes  Single purpose API
# 28                  No        NaN  Single purpose API
# 29                  No        Yes  Single purpose API
# ...                ...        ...                 ...
# 15314               No         No  Single purpose API
# 15315               No         No  Single purpose API
# 15316               No        Yes  Single purpose API
# 15317               No        Yes  Single purpose API
# 15318               No        Yes  Single purpose API
# 15319               No         No  Single purpose API
# 15320               No         No  Single purpose API
# 15321               No        Yes  Single purpose API
# 15322               No        Yes  Single purpose API
# 15323               No         No  Single purpose API
# 15324               No         No  Single purpose API
# 15325               No         No  Single purpose API
# 15326               No         No  Single purpose API
# 15327               No         No  Single purpose API
# 15328               No         No  Single purpose API
# 15329               No        Yes  Single purpose API
# 15330               No         No  Single purpose API
# 15331               No         No  Single purpose API
# 15332               No        Yes  Single purpose API
# 15333               No        NaN  Single purpose API
# 15334               No        Yes  Single purpose API
# 15335               No        Yes  Single purpose API
# 15336               No         No  Single purpose API
# 15337               No        NaN  Single purpose API
# 15338               No        Yes  Single purpose API
# 15339               No         No  Single purpose API
# 15340               No        Yes  Single purpose API
# 15341               No        Yes  Single purpose API
# 15342               No        Yes  Single purpose API
# 15343               No         No  Single purpose API
#
#                                      SecondaryCategories  \
# 0                                                 Viewer
# 1                                               Blogging
# 2                                                  Media
# 3                                                  Video
# 4                                               Webhooks
# 5                                            Advertising
# 6                 Cloud, Text-to-Speech, Voice, Webhooks
# 7                                                    NaN
# 8                                    Auctions, eCommerce
# 9                                         Telephony, USA
# 10                                                Viewer
# 11                                                Social
# 12                                       Cloud, Webhooks
# 13                       Mapping, Mobile, Photos, Search
# 14                                                   NaN
# 15                                  Contracts, Documents
# 16                                                 Cloud
# 17                                                   SEO
# 18                    Database, Mapping, Postal, Weather
# 19                                                  Wiki
# 20     Collaboration, Content Management, Enterprise,...
# 21                          Datacenter, Domains, Hosting
# 22                                      Machine Learning
# 23                                            Enterprise
# 24                                        Mobile, Social
# 25                               Application Development
# 26                                                   NaN
# 27     Business, Directories, eCommerce, Localization...
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 15314                            Recommendations, Travel
# 15315                                             Social
# 15316                        Social, Games, Currency, 3D
# 15317                        Environment, Sustainability
# 15318                                    Encoding, Tools
# 15319                           Images, Widgets, Editing
# 15320                                                Q&A
# 15321                                         Enterprise
# 15322                                                NaN
# 15323                                                NaN
# 15324                              Marketing, Enterprise
# 15325                                                NaN
# 15326                                           Blogging
# 15327                                 Search, SEO, Tools
# 15328                                                NaN
# 15329                                            Hosting
# 15330                                                NaN
# 15331                                                NaN
# 15332                                       Lists, Tasks
# 15333                                          Semantics
# 15334                                                NaN
# 15335                                             Health
# 15336                                           Training
# 15337                                                NaN
# 15338                                            Ratings
# 15339                                     Spam, Blogging
# 15340                                 Blogging, Security
# 15341                                                NaN
# 15342                                     Prices, Stocks
# 15343                                  Japanese, Science
#
#                              SupportEmailAddress  \
# 0                                            NaN
# 1                                api@twitter.com
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                help@twilio.com
# 7                                 office@last.fm
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11     https://secure.delicious.com/help/support
# 12                                           NaN
# 13                            api@foursquare.com
# 14                                           NaN
# 15                            mikeb@docusign.com
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
# 20                              platform@box.com
# 21                                           NaN
# 22                                           NaN
# 23                    atrachtenberg@linkedin.com
# 24                                           NaN
# 25                                           NaN
# 26                                           NaN
# 27                                  api@yelp.com
# 28                                 admin@asot.fm
# 29                                           NaN
# ...                                          ...
# 15314                                        NaN
# 15315                                        NaN
# 15316                                        NaN
# 15317                                        NaN
# 15318                      founders@encoding.com
# 15319                                        NaN
# 15320                                        NaN
# 15321                                        NaN
# 15322                                        NaN
# 15323                                        NaN
# 15324                                        NaN
# 15325                                        NaN
# 15326                                        NaN
# 15327                                        NaN
# 15328                                        NaN
# 15329                                        NaN
# 15330                                        NaN
# 15331                                        NaN
# 15332                        support@todoist.com
# 15333                                        NaN
# 15334                                        NaN
# 15335                                        NaN
# 15336                                        NaN
# 15337                                        NaN
# 15338                                        NaN
# 15339                                        NaN
# 15340                        sales@fraudlabs.com
# 15341                                        NaN
# 15342                           info@xignite.com
# 15343                                        NaN
#
#                                  SupportedRequestFormats  \
# 0       KML, URI Query String/CRUD, XML, VML, JavaScript
# 1                                  URI Query String/CRUD
# 2      Atom, GData, RSS, URI Query String/CRUD, Atom ...
# 3               URI Query String/CRUD, XML, PHP, XML-RPC
# 4                                  URI Query String/CRUD
# 5                                              SOAP, XML
# 6                                  URI Query String/CRUD
# 7                                  URI Query String/CRUD
# 8           XML, SOAP, URI Query String/CRUD, name-value
# 9                                         None Specified
# 10                          KML, XML, GeoRSS, JavaScript
# 11                                        None Specified
# 12                                        None Specified
# 13                                 URI Query String/CRUD
# 14                                            JavaScript
# 15                      SOAP, URI Query String/CRUD, XML
# 16                                 URI Query String/CRUD
# 17                                 URI Query String/CRUD
# 18                                 URI Query String/CRUD
# 19                                 URI Query String/CRUD
# 20                                 URI Query String/CRUD
# 21                                       JSON, SOAP, XML
# 22                                 URI Query String/CRUD
# 23                      JSON, URI Query String/CRUD, XML
# 24                                 URI Query String/CRUD
# 25                                            JavaScript
# 26                                 URI Query String/CRUD
# 27                                                  JSON
# 28                          JSONP, URI Query String/CRUD
# 29                                 URI Query String/CRUD
# ...                                                  ...
# 15314                             OpenSearch, JavaScript
# 15315                                     None Specified
# 15316         XML, SOAP, URI Query String/CRUD, JSON-RPC
# 15317                              URI Query String/CRUD
# 15318                              URI Query String/CRUD
# 15319                                         JavaScript
# 15320                              URI Query String/CRUD
# 15321                                     None Specified
# 15322                                     None Specified
# 15323                                                RSS
# 15324                                     None Specified
# 15325                                     None Specified
# 15326                                     None Specified
# 15327                                          XML, SOAP
# 15328                              URI Query String/CRUD
# 15329                         CSV, URI Query String/CRUD
# 15330                                     None Specified
# 15331                              URI Query String/CRUD
# 15332                              URI Query String/CRUD
# 15333                                            XML-RPC
# 15334                                            XML-RPC
# 15335                         URI Query String/CRUD, PHP
# 15336                              URI Query String/CRUD
# 15337                                          XML, SOAP
# 15338                                     None Specified
# 15339                                            XML-RPC
# 15340                                          SOAP, XML
# 15341                                     None Specified
# 15342              CSV, SOAP, XML, URI Query String/CRUD
# 15343                                   Atom, OpenSearch
#
#                   SupportedResponseFormats                            Title
# 0                           JSON, KML, XML                  Google Maps API
# 1                     Atom, JSON, RSS, XML                      Twitter API
# 2              XML, JSON, GData, Atom, RSS                      YouTube API
# 3                  JSON, XML, PHP, XML-RPC                       Flickr API
# 4                                     JSON                     Facebook API
# 5                                SOAP, XML   Amazon Product Advertising API
# 6                     CSV, HTML, JSON, XML                       Twilio API
# 7                                JSON, XML                      Last.fm API
# 8                          XML, SOAP, JSON                         eBay API
# 9                                      XML                   Twilio SMS API
# 10                                     KML          Microsoft Bing Maps API
# 11                                     XML                  del.icio.us API
# 12                          None Specified            Google App Engine API
# 13                                    JSON                   Foursquare API
# 14                                     XML              Google Homepage API
# 15                         JSON, SOAP, XML          DocuSign Enterprise API
# 16                               JSON, XML                    Amazon S3 API
# 17                               JSON, XML               Google AdSense API
# 18     CSV, JSON, KML, RDF, RSS, Text, XML                     GeoNames API
# 19                  JSON, XML, JSONFM, PHP                    Wikipedia API
# 20                                    JSON                          Box API
# 21                               SOAP, XML                   Amazon EC2 API
# 22                                    JSON                         Bing API
# 23                               JSON, XML                     LinkedIn API
# 24                                    JSON              Instagram Graph API
# 25                          None Specified        Google AJAX Libraries API
# 26                               JSON, XML                   Yahoo BOSS API
# 27                          None Specified                  Yelp Fusion API
# 28                             JSON, JSONP            A State of Trance API
# 29                               JSON, XML   Google Analytics Managment API
# ...                                    ...                              ...
# 15314                             RSS, XML                     RatePubs API
# 15315                                  XML                   Wipee List API
# 15316                      XML, JSON, SOAP                       VirWoX API
# 15317                            JSON, XML                      OpenEco API
# 15318                            JSON, XML                 Encoding.com API
# 15319                       None Specified                   WebResizer API
# 15320                                 JSON                      Dooblet API
# 15321                                  XML                     TickSpot API
# 15322                                  XML                       Dilogs API
# 15323                                  RSS                    to.uri.st API
# 15324                                  XML                      AdSpeed API
# 15325                       None Specified                     SimpleDB API
# 15326                                 Text                  Tweetburner API
# 15327                            SOAP, XML                      Wordpot API
# 15328                                 JSON                     FindMeOn API
# 15329                       JSON, XML, CSV                       GoGrid API
# 15330                                  XML                  Seattle 2.0 API
# 15331                            JSON, XML                FreedomSpeaks API
# 15332                                 JSON                 Todoist Sync API
# 15333                                  XML        Ping the Semantic Web API
# 15334                                  XML                   PhoneGnome API
# 15335                            JSON, XML               Walker Tracker API
# 15336                                 JSON                Dojo Learning API
# 15337                            SOAP, XML                     LandGrab API
# 15338                                  XML                    IZEARanks API
# 15339                                  XML                       Mollom API
# 15340                            SOAP, XML  FraudLabs MailBox Validator API
# 15341                                  XML                       Weewar API
# 15342                 XML, SOAP, JSON, CSV          XigniteGlobalQuotes API
# 15343                            Atom, XML                         PDBj API
#
# [15344 rows x 20 columns]

# %%
df.shape
# Out:
# (15344, 20)

# %%
df.columns
# Out:
# Index(['APIEndpoint', 'APIForumMessageBoards', 'APIPortalHomePage',
#        'APIProvider', 'ArchitecturalStyle', 'AuthenticationModel',
#        'Description', 'DeviceSpecific', 'DocsHomePageUR',
#        'IsThisanUnofficialAPI', 'IstheAPIDesign', 'PrimaryCategory',
#        'RestrictedAccess', 'SSLSupport', 'Scope', 'SecondaryCategories',
#        'SupportEmailAddress', 'SupportedRequestFormats',
#        'SupportedResponseFormats', 'Title'],
#       dtype='object')

# %%
label = df.loc[:, 'PrimaryCategory']
label
# Out:
# 0                                Mapping
# 1                                 Social
# 2                                  Video
# 3                                 Photos
# 4                                 Social
# 5                              eCommerce
# 6                              Telephony
# 7                                  Music
# 8                                 Search
# 9                              Messaging
# 10                               Mapping
# 11                             Bookmarks
# 12                                 Tools
# 13                                Social
# 14                               Widgets
# 15                  Electronic Signature
# 16                               Storage
# 17                           Advertising
# 18                             Reference
# 19                             Reference
# 20                               Content
# 21                                 Cloud
# 22                                Search
# 23                                Social
# 24                                Photos
# 25                               Library
# 26                                Search
# 27                       Recommendations
# 28                                 Music
# 29                             Analytics
#                       ...
# 15314                               Food
# 15315                 Project Management
# 15316                          Financial
# 15317                              Other
# 15318                              Video
# 15319                             Photos
# 15320                             Search
# 15321                 Project Management
# 15322                             Sports
# 15323                             Travel
# 15324                        Advertising
# 15325                            Storage
# 15326                             Social
# 15327                        Advertising
# 15328                             Social
# 15329                              Cloud
# 15330                             Events
# 15331                         Government
# 15332    Personal Information Management
# 15333                          Standards
# 15334                          Telephony
# 15335                             Sports
# 15336                         Enterprise
# 15337                              Games
# 15338                           Blogging
# 15339                           Security
# 15340                              Email
# 15341                              Games
# 15342                          Financial
# 15343                            Medical
# Name: PrimaryCategory, Length: 15344, dtype: object

# %%
label.isnull().sum()
# Out:
# 35

# %%
label[label.isnull()]
# Out:
# 93       NaN
# 113      NaN
# 281      NaN
# 298      NaN
# 587      NaN
# 629      NaN
# 639      NaN
# 659      NaN
# 982      NaN
# 1307     NaN
# 1359     NaN
# 1371     NaN
# 1387     NaN
# 1920     NaN
# 3140     NaN
# 4066     NaN
# 4666     NaN
# 11668    NaN
# 12240    NaN
# 12465    NaN
# 12750    NaN
# 12813    NaN
# 13378    NaN
# 13423    NaN
# 13544    NaN
# 13819    NaN
# 14100    NaN
# 14637    NaN
# 14659    NaN
# 14682    NaN
# 14687    NaN
# 14852    NaN
# 14876    NaN
# 14887    NaN
# 15267    NaN
# Name: PrimaryCategory, dtype: object

# %%
data = df.loc[label.notnull(), :]

# %%
data.loc[2, 'Description']
# Out:
# "The Data API allows users to integrate their program with YouTube and allow it to perform many of the operations available on the website. It provides the capability to search for videos, retrieve standard feeds, and see related content. A program can also authenticate as a user to upload videos, modify user playlists, and more. This integration can be used for a variety of uses such as developing a web application allowing users to upload video to YouTube, or a device or desktop application that brings the YouTube experience to a new platform. The Data API gives users programmatic access to the video and user information stored on YouTube. This can be used to personalize a web site or application with the user's existing information as well as perform actions like commenting on and rating videos. This RESTful API provides responses in XML format."

# %%
data.loc[2, 'PrimaryCategory']
# Out:
# 'Video'

# %%
data.loc[2, 'APIProvider']
# Out:
# 'Google'

# %%
data.loc[:, 'PrimaryCategory'].head()
# Out:
# 0    Mapping
# 1     Social
# 2      Video
# 3     Photos
# 4     Social
# Name: PrimaryCategory, dtype: object

# %%
len(set(data.loc[:, 'PrimaryCategory']))
# Out:
# 401

# %%
data.loc[:, 'PrimaryCategory'].groupby()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-bb21e72a52b4> in <module>()
# ----> 1 data.loc[:, 'PrimaryCategory'].groupby()
#
# /Applications/conda/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4410
#    4411         if level is None and by is None:
# -> 4412             raise TypeError("You have to supply one of 'by' and 'level'")
#    4413         axis = self._get_axis_number(axis)
#    4414         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#
# TypeError: You have to supply one of 'by' and 'level'

# %%
finaldata = pd.DataFrame(data, columns=['Description', 'PrimaryCategory'])

# %%
finaldata.shape
# Out:
# (15309, 2)

# %%
finaldata.loc[[2]]
# Out:
#                                          Description PrimaryCategory
# 2  The Data API allows users to integrate their p...           Video

# %%
labelcount = finaldata.PrimaryCategory.value_counts()
labelcount.count()
# Out:
# 401

# %%
labelcount[labelcount > 100].count()
# Out:
# 41

# %%
labelcount[labelcount > 200].count()
# Out:
# 22

# %%
labelcount[1:10]
# Out:
# Financial     687
# Messaging     511
# eCommerce     466
# Payments      460
# Social        433
# Enterprise    412
# Mapping       362
# Government    304
# Telephony     300
# Name: PrimaryCategory, dtype: int64

# %%
labelcount[1:20]
# Out:
# Financial         687
# Messaging         511
# eCommerce         466
# Payments          460
# Social            433
# Enterprise        412
# Mapping           362
# Government        304
# Telephony         300
# Science           298
# Email             255
# Video             251
# Reference         251
# Security          251
# Search            251
# Travel            243
# Sports            228
# Advertising       224
# Transportation    218
# Name: PrimaryCategory, dtype: int64

# %%
labelcount[1:30]
# Out:
# Financial             687
# Messaging             511
# eCommerce             466
# Payments              460
# Social                433
# Enterprise            412
# Mapping               362
# Government            304
# Telephony             300
# Science               298
# Email                 255
# Video                 251
# Reference             251
# Security              251
# Search                251
# Travel                243
# Sports                228
# Advertising           224
# Transportation        218
# Education             215
# Games                 203
# Music                 193
# Photos                185
# Cloud                 173
# Other                 158
# Bitcoin               143
# Data                  142
# Project Management    142
# Database              136
# Name: PrimaryCategory, dtype: int64

# %%
labelcount[1:40]
# Out:
# Financial                  687
# Messaging                  511
# eCommerce                  466
# Payments                   460
# Social                     433
# Enterprise                 412
# Mapping                    362
# Government                 304
# Telephony                  300
# Science                    298
# Email                      255
# Video                      251
# Reference                  251
# Security                   251
# Search                     251
# Travel                     243
# Sports                     228
# Advertising                224
# Transportation             218
# Education                  215
# Games                      203
# Music                      193
# Photos                     185
# Cloud                      173
# Other                      158
# Bitcoin                    143
# Data                       142
# Project Management         142
# Database                   136
# Shipping                   136
# Backend                    134
# Stocks                     133
# Weather                    132
# Application Development    123
# Analytics                  115
# Internet of Things         113
# Banking                    111
# Medical                    111
# Events                     108
# Name: PrimaryCategory, dtype: int64

# %%
labelcount[1:50]
# Out:
# Financial                  687
# Messaging                  511
# eCommerce                  466
# Payments                   460
# Social                     433
# Enterprise                 412
# Mapping                    362
# Government                 304
# Telephony                  300
# Science                    298
# Email                      255
# Video                      251
# Reference                  251
# Security                   251
# Search                     251
# Travel                     243
# Sports                     228
# Advertising                224
# Transportation             218
# Education                  215
# Games                      203
# Music                      193
# Photos                     185
# Cloud                      173
# Other                      158
# Bitcoin                    143
# Data                       142
# Project Management         142
# Database                   136
# Shipping                   136
# Backend                    134
# Stocks                     133
# Weather                    132
# Application Development    123
# Analytics                  115
# Internet of Things         113
# Banking                    111
# Medical                    111
# Events                     108
# Real Estate                108
# Storage                     99
# Entertainment               95
# File Sharing                86
# Domains                     84
# Images                      83
# News Services               82
# Chat                        82
# Media                       82
# Marketing                   81
# Name: PrimaryCategory, dtype: int64

# %%
labelcount[1:100]
# Out:
# Financial                           687
# Messaging                           511
# eCommerce                           466
# Payments                            460
# Social                              433
# Enterprise                          412
# Mapping                             362
# Government                          304
# Telephony                           300
# Science                             298
# Email                               255
# Video                               251
# Reference                           251
# Security                            251
# Search                              251
# Travel                              243
# Sports                              228
# Advertising                         224
# Transportation                      218
# Education                           215
# Games                               203
# Music                               193
# Photos                              185
# Cloud                               173
# Other                               158
# Bitcoin                             143
# Data                                142
# Project Management                  142
# Database                            136
# Shipping                            136
#                                    ...
# Customer Relationship Management     43
# Calendars                            43
# Air Travel                           42
# Content                              42
# Translation                          42
# Sentiment                            42
# Bots                                 41
# Artificial Intelligence              39
# Machine Learning                     39
# Voice                                39
# Platform-as-a-Service                37
# Authentication                       35
# SEO                                  34
# Human Resources                      33
# Collaboration                        33
# Personal Information Management      32
# Agriculture                          32
# Library                              31
# Applications                         31
# Documents                            31
# Addresses                            30
# Big Data                             30
# Printing                             30
# Conversions                          30
# Astronomy                            30
# Data-as-a-Service                    30
# Sales                                29
# Browsers                             29
# Notifications                        29
# Bookmarks                            28
# Name: PrimaryCategory, Length: 99, dtype: int64

# %%
labelcount[labelcount < 10].count()
# Out:
# 217

# %%
num_bins = 100
n, bins, patches = plt.hist(labelcount, num_bins)
plt.show()

# %%
labelcount[labelcount > 100].count()
# Out:
# 41
